# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/applemobilitytrends-2021-04-20.csv")
len(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 4691

# %%
df.head()
# Out:
#          geo_type     region  ... 2021-04-19 2021-04-20
# 0  country/region    Albania  ...     116.15     114.33
# 1  country/region    Albania  ...     149.68     142.30
# 2  country/region  Argentina  ...      60.19      63.25
# 3  country/region  Argentina  ...      56.19      58.81
# 4  country/region  Australia  ...     109.87     113.70
#
# [5 rows x 470 columns]

# %%
london = df.loc[df['region']=='London']
london.head()
# Out:
#     geo_type  region transportation_type  ... 2021-04-18 2021-04-19 2021-04-20
# 541     city  London             driving  ...      93.54      93.38      98.36
# 542     city  London             transit  ...      82.39      78.93      84.01
# 543     city  London             walking  ...      77.32      74.08      80.72
#
# [3 rows x 470 columns]

# %%
frame = london.loc[london['transportation_type']=='transit']
frame.head()
# Out:
#     geo_type  region transportation_type  ... 2021-04-18 2021-04-19 2021-04-20
# 542     city  London             transit  ...      82.39      78.93      84.01
#
# [1 rows x 470 columns]

# %%
result = frame.transpose()
result.head(7)
# Out:
#                                 542
# geo_type                       city
# region                       London
# transportation_type         transit
# alternative_name                NaN
# sub-region                  England
# country              United Kingdom
# 2020-01-13                      100

# %%
print(len(result))
# Out:
# 470

# %%
final = result.tail(len(result)-6)
final.head()
# Out:
#                542
# 2020-01-13     100
# 2020-01-14  105.14
# 2020-01-15  107.06
# 2020-01-16  106.08
# 2020-01-17  115.13

# %%
final.to_csv('version1.csv')

# %%
final = pd.read_csv('version1.csv')

# %%
final.head()
# Out:
#    Unnamed: 0     542
# 0  2020-01-13  100.00
# 1  2020-01-14  105.14
# 2  2020-01-15  107.06
# 3  2020-01-16  106.08
# 4  2020-01-17  115.13

# %%
final.columns = ['date', 'mobility_index']

# %%
final.head()
# Out:
#          date  mobility_index
# 0  2020-01-13          100.00
# 1  2020-01-14          105.14
# 2  2020-01-15          107.06
# 3  2020-01-16          106.08
# 4  2020-01-17          115.13

# %%
final.to_csv('apple_mobility.csv', index=False)
